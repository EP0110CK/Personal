# %%
def get_income():
    income = float(input("Enter your total income: "))
    return income

def get_expenses():
    expenses = {}
    while True:
        category = input("Enter expense category (or type 'done' to finish): ")
        if category.lower() == 'done':
            break
        amount = float(input(f"Enter amount for {category}: "))
        expenses[category] = amount
    return expenses
    
def calculate_total(expenses):
    return sum(expenses.values())

def display_budget(income, expenses):
    total_expenses = calculate_total(expenses)
    net_savings = income - total_expenses
    
    print("\n--- Budget Summary ---")
    print(f"Total Income: ${income:.2f}")
    print("Expenses:")
    for category, amount in expenses.items():
        print(f" {category}: ${amount:.2f}")
    print(f"Total Expenses: ${total_expenses:.2f}")
    print(f"Net Savings: ${net_savings:.2f}")
    
def main():
    income = get_income()
    expenses = get_expenses()
    display_budget(income, expenses)
    
if __name__ == "__main__":
    main()
# Out:
# Enter your total income: 1600
# Enter expense category (or type 'done' to finish): Gas
# Enter amount for Gas: 150
# Enter expense category (or type 'done' to finish): Food
# Enter amount for Food: 400
# Enter expense category (or type 'done' to finish): Fitness
# Enter amount for Fitness: 100
# Enter expense category (or type 'done' to finish): Retirement
# Enter amount for Retirement: 350
# Enter expense category (or type 'done' to finish): Phone
# Enter amount for Phone: 100
# Enter expense category (or type 'done' to finish): Travel
# Enter amount for Travel: 500
# Enter expense category (or type 'done' to finish): done
#
# --- Budget Summary ---
# Total Income: $1600.00
# Expenses:
#  Gas: $150.00
#  Food: $400.00
#  Fitness: $100.00
#  Retirement: $350.00
#  Phone: $100.00
#  Travel: $500.00
# Total Expenses: $1600.00
# Net Savings: $0.00
