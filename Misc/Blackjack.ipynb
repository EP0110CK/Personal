# %%
import random

# %%
def deal_card():
    "Deals a random card from a deck."
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    return random.choice(cards)

# %%
def calculate_score(hand):
    "Calculates the score of a hand, adjusting for Aces."
    score = sum(hand)
    if score > 21 and 11 in hand:
        score -= 10
    return score

# %%
def compare(user_score, dealer_score):
    "Compares the user and dealer scores, determining the winner."
    if user_score == dealer_score:
        return "Draw"
    elif dealer_score == 21:
        return "Dealer has BlackJack! You lose."
    elif user_score == 21:
        return "Blackjack! You win."
    elif user_score > 21:
        return "You busted! You lose."
    elif dealer_score > 21:
        return "Dealer busted! You win."
    elif user_score > dealer_score:
        return "You win!"
    else:
        return "You lose."

# %%
def play_game():
    "Plays a game of Blackjack."
    user_cards = []
    dealer_cards = []

    for _ in range(2):
        user_cards.append(deal_card())
        dealer_card.append(deal_card())

    while True:
        user_score = calculate_score(user_cards)
        dealer_score = calculate_score(dealer_cards)

        print(f"Your cards: {user_cards}, current score: {user_score}")
        print(f"Dealer's first card: {dealer_cards[0]}")

    if user_score == 21 or dealer_score == 21 or user_score > 21:
        break

    choice = input("Do you want to 'hit' or 'stand'?").lower()
    if choice == "hit":
        user_cards.append(deal_card())
    else:
        break

    while dealer_score < 17:
        dealer_cards.append(deal_card())
        dealer_score = calculate_score(dealer_cards)

    print(f"Your final hand: {user_cards, final score: {user_score}")
    print(f"Dealer's final hand: {dealer_cards}, final score: {dealer_score}")
    print(compare(user_score, dealer_score))

while input("Do you want to play a game of Blackjack? (y/n): ".lower() == "y":
    play_game()

# %%
import random

def deal_card():
    """Deals a random card from a deck."""
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    return random.choice(cards)

def calculate_score(hand):
    """Calculates the score of a hand, adjusting for Aces."""
    score = sum(hand)
    if score > 21 and 11 in hand:
        score -= 10
    return score

def compare(user_score, dealer_score):
    """Compares the user and dealer scores, determining the winner."""
    if user_score == dealer_score:
        return "Draw"
    elif dealer_score == 21:
        return "Dealer has Blackjack! You lose."
    elif user_score == 21:
        return "Blackjack! You win!"
    elif user_score > 21:
        return "You busted! You lose."
    elif dealer_score > 21:
        return "Dealer busted! You win."
    elif user_score > dealer_score:
        return "You win!"
    else:
        return "You lose."

def play_game():
    """Plays a game of Blackjack."""
    user_cards = []
    dealer_cards = []

    for _ in range(2):
        user_cards.append(deal_card())
        dealer_cards.append(deal_card())

    while True:
        user_score = calculate_score(user_cards)
        dealer_score = calculate_score(dealer_cards)

        print(f"Your cards: {user_cards}, current score: {user_score}")
        print(f"Dealer's first card: {dealer_cards[0]}")

        if user_score == 21 or dealer_score == 21 or user_score > 21:
            break

        choice = input("Do you want to 'hit' or 'stand'? ").lower()
        if choice == "hit":
            user_cards.append(deal_card())
        else:
            break

    while dealer_score < 17:
        dealer_cards.append(deal_card())
        dealer_score = calculate_score(dealer_cards)

    print(f"Your final hand: {user_cards}, final score: {user_score}")
    print(f"Dealer's final hand: {dealer_cards}, final score: {dealer_score}")
    print(compare(user_score, dealer_score))

while input("Do you want to play a game of Blackjack? (y/n): ").lower() == "y":
    play_game()
# Out:
# Do you want to play a game of Blackjack? (y/n):  y
# Your cards: [4, 2], current score: 6
# Dealer's first card: 6
# Do you want to 'hit' or 'stand'?  hit
# Your cards: [4, 2, 4], current score: 10
# Dealer's first card: 6
# Do you want to 'hit' or 'stand'?  hit
# Your cards: [4, 2, 4, 10], current score: 20
# Dealer's first card: 6
# Do you want to 'hit' or 'stand'?  stand
# Your final hand: [4, 2, 4, 10], final score: 20
# Dealer's final hand: [6, 10, 5], final score: 21
# Dealer has Blackjack! You lose.
# Do you want to play a game of Blackjack? (y/n):  y
# Your cards: [4, 11], current score: 15
# Dealer's first card: 10
