# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_excel(r"C:\Users\Ethan\Downloads\CarResearchData.xlsx")
print(df)
# Out:
#     Year        Make   Model     Trim  Price  Mileage Transmission  City MPG  \
# 0   2018       Honda  Accord    Sport  14600    10000          CVT        29
# 1   2019      Nissan  Sentra       SV  16490    27854          CVT        29
# 2   2020         Kia   Forte  GT-Line  17499    20524          CVT        29
# 3   2021      Nissan  Sentra       SV  17500    21661          CVT        29
# 4   2021      Nissan  Sentra       SV  17899    21305          CVT        29
# ..   ...         ...     ...      ...    ...      ...          ...       ...
# 62  2024  Volkswagen   Jetta        S  19715       10    Automatic        30
# 63  2024  Volkswagen   Jetta        S  19715        8    Automatic        30
# 64  2021       Honda   Civic       LX  19750    27047          CVT        30
# 65  2023  Volkswagen   Jetta        S  19750    28324    Automatic        31
# 66  2021     Hyundai  Sonata       SE  19790    18172    Automatic        28
#
# ...

# %%
df.describe()
# Out:
#               Year         Price       Mileage   City MPG  Highway MPG  \
# count    67.000000     67.000000     67.000000  67.000000    67.000000
# mean   2021.477612  18611.865672  16974.089552  28.686567    38.731343
# std       1.636313   1012.757560  10041.933811   1.427107     1.805565
# min    2018.000000  14600.000000      0.000000  23.000000    32.000000
# 25%    2020.500000  18000.000000   9340.500000  28.000000    38.000000
# 50%    2021.000000  18929.000000  21126.000000  29.000000    39.000000
# 75%    2023.000000  19375.000000  25064.500000  30.000000    40.000000
# max    2024.000000  19900.000000  29507.000000  31.000000    41.000000
#
#        Combined MPG  Keyless Start  Alloy Wheels  Accidents/ Damage Reported
# count     67.000000      67.000000     67.000000                   67.000000
# mean      33.708955       0.567164      0.820896                    0.253731
# std        1.554927       0.499208      0.386334                    0.438430
# ...

# %%
plt.scatter(df['Mileage'], df['Price'])
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.title('Scatter Plot of Price and Mileage')

m, b=np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color = 'red')

plt.show()

# %%
price = df['Price']
mileage = df['Mileage']
fuel_efficiency = ['Combined MPG']
keyless_start = ['Keyless Start']
alloy_wheel = ['Alloy Wheels']
accidents_reported = ['Accidents/Damage Reported']

min_price = 14600
max_price = 19900

min_mileage = 0
max_mileage = 29507

# %%
def calculate_car_score(price, mileage, fuel_efficiency, keyless_start, alloy_wheel, accidents_reported):
    """Calculates a car score based on various factors."""

# %%
price_weight = 0.3
mileage_weight = 0.3
fuel_weight = 0.15
keyless_weight = 0.1
alloy_weight = 0.05
accidents_weight = 0.1

prices_normalized = (price - min_price)/(max_price - min_price)
mileage_normalized = (mileage - min_mileage)/(max_mileage - min_mileage)

# %%
score = (price_weight*prices_normalized + 
         mileage_weight*mileage_normalized + 
         fuel_weight*int(fuel_efficiency) + 
         keyless_weight*int(keyless_start) + 
         alloy_weight*int(alloy_wheel) + 
         accidents_weight*int(accidents_reported)
        )

return score
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 score = (price_weight*prices_normalized +
#       2          mileage_weight*mileage_normalized +
# ----> 3          fuel_weight*int(fuel_efficiency) +
#       4          keyless_weight*int(keyless_start) +
#       5          alloy_weight*int(alloy_wheel) +
#       6          accidents_weight*int(accidents_reported)
#       7         )
#       9 return score
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'
