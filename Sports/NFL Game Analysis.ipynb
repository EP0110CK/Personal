# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
games = pd.read_csv("games.csv")

games
# Out:
#     season  week    gameDate      gameId gameTimeEastern  HomeScore  \
# 0     2017     1  09/10/2017  2017091004        13:00:00         35
# 1     2017     1  09/07/2017  2017090700        20:30:00         27
# 2     2017     1  09/10/2017  2017091003        13:00:00         18
# 3     2017     1  09/10/2017  2017091002        13:00:00          0
# 4     2017     1  09/10/2017  2017091000        13:00:00         21
# ..     ...   ...         ...         ...             ...        ...
# 86    2017     6  10/15/2017  2017101503        13:00:00         23
# 87    2017     6  10/15/2017  2017101510        16:25:00         16
# 88    2017     6  10/12/2017  2017101200        20:25:00         23
# 89    2017     6  10/16/2017  2017101600        20:30:00         36
# 90    2017     6  10/15/2017  2017101501        13:00:00         24
#
#     VisitorScore homeTeamAbbr visitorTeamAbbr       homeDisplayName  ...  \
# 0             23          DET             ARI         Detroit Lions  ...
# ...

# %%
games.isnull().sum()
# Out:
# season                 0
# week                   0
# gameDate               0
# gameId                 0
# gameTimeEastern        0
# HomeScore              0
# VisitorScore           0
# homeTeamAbbr           0
# visitorTeamAbbr        0
# homeDisplayName        0
# visitorDisplayName     0
# Stadium                0
# Location               0
# StadiumType            5
# Turf                   0
# GameLength             0
# GameWeather            7
# Temperature           11
# Humidity               1
# WindSpeed             15
# WindDirection         17
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 games['Temperature'] = games['Temperature'].fillna(games['Temperature'].mean())
# ----> 2 games['WindSpeed'] = games['WindSpeed'].fillna(games['WindSpeed'].mean())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
# ...
