# %%
import pandas as pd
import plotly.express as px
import ipywidgets as widgets
from IPython.display import display

# --- Sample Dummy Data ---
# Replace this with real NFL standings data
teams = ['49ers', 'Cowboys', 'Eagles', 'Chiefs', 'Bills']
weeks = list(range(1, 19))

# Create dummy win-loss data
data = []
for week in weeks:
    for team in teams:
        wins = min(week, max(0, int(week / 2 + (hash(team + str(week)) % 3 - 1))))
        losses = week - wins
        data.append({'Week': week, 'Team': team, 'Wins': wins, 'Losses': losses})

df = pd.DataFrame(data)

# --- Plotting Function ---
def plot_standings(week):
    week_data = df[df['Week'] == week]
    fig = px.bar(
        week_data,
        x='Team',
        y='Wins',
        color='Team',
        title=f'NFL Team Wins - Week {week}',
        labels={'Wins': 'Number of Wins'},
        height=500
    )
    fig.update_layout(showlegend=False)
    fig.show()

# --- Slider Widget ---
week_slider = widgets.IntSlider(
    value=1,
    min=1,
    max=18,
    step=1,
    description='Week:',
    continuous_update=False
)

# --- Link Slider to Plot ---
widgets.interact(plot_standings, week=week_slider)
# Out:
# interactive(children=(IntSlider(value=1, continuous_update=False, description='Week:', max=18, min=1), Output(…
# <function __main__.plot_standings(week)>

# %%
import pandas as pd
import dash
from dash import dcc, html, Input, Output
from dash import dash_table

# Dummy data generator for testing
def generate_dummy_data():
    import numpy as np
    teams = {
        "AFC East": ["Bills", "Dolphins", "Patriots", "Jets"],
        "AFC North": ["Ravens", "Bengals", "Browns", "Steelers"],
        "AFC South": ["Texans", "Colts", "Jaguars", "Titans"],
        "AFC West": ["Chiefs", "Broncos", "Raiders", "Chargers"],
        "NFC East": ["Eagles", "Cowboys", "Giants", "Commanders"],
        "NFC North": ["Lions", "Vikings", "Packers", "Bears"],
        "NFC South": ["Buccaneers", "Saints", "Falcons", "Panthers"],
        "NFC West": ["49ers", "Rams", "Seahawks", "Cardinals"]
    }

    data = []
    for week in range(1, 19):  # Weeks 1-18
        for division, team_list in teams.items():
            for team in team_list:
                wins = np.random.randint(0, week+1)
                losses = week - wins
                pf = np.random.randint(150, 350)
                pa = np.random.randint(150, 350)
                data.append({
                    "Week": week,
                    "Team": team,
                    "Division": division,
                    "Wins": wins,
                    "Losses": losses,
                    "PointsFor": pf,
                    "PointsAgainst": pa
                })

    return pd.DataFrame(data)

# Load or generate your weekly NFL data
df = generate_dummy_data()

# Initialize the Dash app
app = dash.Dash(__name__)
app.title = "NFL 2024 Standings by Week"

# Layout
app.layout = html.Div([
    html.H1("NFL 2024 Division Standings"),
    
    dcc.Slider(
        id='week-slider',
        min=1,
        max=18,
        step=1,
        value=1,
        marks={i: f"Week {i}" for i in range(1, 19)},
    ),
    
    html.Div(id='standings-output')
], style={'width': '80%', 'margin': 'auto'})


# Callback to update standings
@app.callback(
    Output('standings-output', 'children'),
    Input('week-slider', 'value')
)
def update_standings(week):
    filtered = df[df['Week'] == week].copy()

    # Calculate win percentage
    filtered['WinPct'] = filtered['Wins'] / (filtered['Wins'] + filtered['Losses']).replace(0, 1)

    # Sort by WinPct, PointsFor (desc), PointsAgainst (asc)
    filtered.sort_values(
        by=['Division', 'WinPct', 'PointsFor', 'PointsAgainst'],
        ascending=[True, False, False, True],
        inplace=True
    )

    output = []
    for division in filtered['Division'].unique():
        div_df = filtered[filtered['Division'] == division]
        table = dash_table.DataTable(
            columns=[
                {"name": "Team", "id": "Team"},
                {"name": "W", "id": "Wins"},
                {"name": "L", "id": "Losses"},
                {"name": "Win %", "id": "WinPct", "type": "numeric", "format": {'specifier': '.3f'}},
                {"name": "PF", "id": "PointsFor"},
                {"name": "PA", "id": "PointsAgainst"},
            ],
            data=div_df.to_dict('records'),
            style_table={'overflowX': 'auto'},
            style_header={'fontWeight': 'bold'},
            style_cell={'textAlign': 'center'},
        )
        output.append(html.H3(division))
        output.append(table)

    return output

# Run app
if __name__ == "__main__":
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 106
#     104 # Run app
#     105 if __name__ == "__main__":
# --> 106     app.run(debug=True)
#
# File ~\anaconda3\Lib\site-packages\dash\dash.py:2363, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_disable_version_check, dev_tools_prune_errors, **flask_run_options)
#    2360             extra_files.append(path)
#    2362 if jupyter_dash.active:
# -> 2363     jupyter_dash.run_app(
#    2364         self,
#    2365         mode=jupyter_mode,
#    2366         width=jupyter_width,
#    2367         height=jupyter_height,
#    2368         host=host,
#    2369         port=port,
#    2370         server_url=jupyter_server_url,
#    2371     )
#    2372 else:
#    2373     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File ~\anaconda3\Lib\site-packages\dash\_jupyter.py:408, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     406     display(HTML(msg))
#     407 else:
# --> 408     raise final_error
#
# File ~\anaconda3\Lib\site-packages\dash\_jupyter.py:395, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     392         raise err
#     394 try:
# --> 395     wait_for_app()
#     397     if self.in_colab:
#     398         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File ~\anaconda3\Lib\site-packages\retrying.py:55, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      53 @wraps(f)
#      54 def wrapped_f(*args, **kw):
# ---> 55     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\anaconda3\Lib\site-packages\retrying.py:289, in Retrying.call(self, fn, *args, **kwargs)
#     286 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     287     if not self._wrap_exception and attempt.has_exception:
#     288         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 289         raise attempt.get()
#     290     else:
#     291         raise RetryError(attempt)
#
# File ~\anaconda3\Lib\site-packages\retrying.py:326, in Attempt.get(self, wrap_exception)
#     324     else:
#     325         exc_type, exc, tb = self.value
# --> 326         raise exc.with_traceback(tb)
#     327 else:
#     328     return self.value
#
# File ~\anaconda3\Lib\site-packages\retrying.py:273, in Retrying.call(self, fn, *args, **kwargs)
#     270     self._before_attempts(attempt_number)
#     272 try:
# --> 273     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     274 except Exception:
#     275     tb = sys.exc_info()
#
# File ~\anaconda3\Lib\site-packages\dash\_jupyter.py:386, in JupyterDash.run_app.<locals>.wait_for_app()
#     384     if res != "Alive":
#     385         url = f"http://{host}:{port}"
# --> 386         raise OSError(
#     387             f"Address '{url}' already in use.\n"
#     388             "    Try passing a different port to run."
#     389         )
#     390 except requests.ConnectionError as err:
#     391     _get_error()
#
# OSError: Address 'http://127.0.0.1:8050' already in use.
#     Try passing a different port to run.

# %%
pip install nfl_data_py
# Out:
# Requirement already satisfied: nfl_data_py in c:\users\ethan\appdata\roaming\python\python311\site-packages (0.3.3)
# Requirement already satisfied: numpy<2.0,>=1.0 in c:\users\ethan\anaconda3\lib\site-packages (from nfl_data_py) (1.24.3)
# Requirement already satisfied: pandas<2.0,>=1.0 in c:\users\ethan\anaconda3\lib\site-packages (from nfl_data_py) (1.5.3)
# Requirement already satisfied: appdirs>1 in c:\users\ethan\anaconda3\lib\site-packages (from nfl_data_py) (1.4.4)
# Requirement already satisfied: fastparquet>0.5 in c:\users\ethan\appdata\roaming\python\python311\site-packages (from nfl_data_py) (2024.11.0)
# Requirement already satisfied: cramjam>=2.3 in c:\users\ethan\anaconda3\lib\site-packages (from fastparquet>0.5->nfl_data_py) (2.10.0)
# Requirement already satisfied: fsspec in c:\users\ethan\anaconda3\lib\site-packages (from fastparquet>0.5->nfl_data_py) (2023.4.0)
# Requirement already satisfied: packaging in c:\users\ethan\anaconda3\lib\site-packages (from fastparquet>0.5->nfl_data_py) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ethan\anaconda3\lib\site-packages (from pandas<2.0,>=1.0->nfl_data_py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ethan\anaconda3\lib\site-packages (from pandas<2.0,>=1.0->nfl_data_py) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\ethan\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<2.0,>=1.0->nfl_data_py) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nfl_data_py import import_pbp_data
import pandas as pd

# Get play-by-play data for the full 2024 season (once it's available)
pbp = import_pbp_data([2024])

# Save a copy to avoid repeated downloads
pbp.to_csv("nfl_2024_pbp.csv", index=False)
# Out:
# 2024 done.
# Downcasting floats.

# %%
weekly_summary = (
    pbp[pbp['play_type'].notna()]  # remove non-plays
    .groupby(['week', 'posteam'])
    .agg({
        'posteam_score': 'max',
        'defteam_score': 'max',
    })
    .reset_index()
)
